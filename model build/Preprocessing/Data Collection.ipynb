# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
drive_path = "/content/drive/MyDrive/ML Project"
collection_path = drive_path + "/Collection"
dataset_path = drive_path + "/Dataset"

# %% [markdown]
# Only run this two cells below once

# %%
# !unzip "/content/drive/MyDrive/ML Project/archive.zip" -d "/content/drive/MyDrive/ML Project/Collection"

# %%
# !unzip  "/content/drive/MyDrive/ML Project/archive (1).zip" -d "/content/drive/MyDrive/ML Project/Collection"

# %%
import os
import shutil
os.listdir(collection_path)
# Out:
# ['COVID_IEEE', 'NonAugmentedTrain', 'Covid19 Positive']

# %% [markdown]
# I have to collect images from different sources. Here there are 3 folders in which we have dataset images.
#
# Most of images are repeated in folders so need to keep a track of that while extracting them for our project.
#
# Most of images belong to IEEE dataset.

# %%
dataset1_covid  = collection_path + "/COVID_IEEE/covid"
dataset1_normal = collection_path + "/COVID_IEEE/normal"
dataset2_covid  = collection_path + "/NonAugmentedTrain/COVID-19"
dataset2_normal = collection_path + "/NonAugmentedTrain/Normal"

my_dataset_covid = dataset_path + "/COVID"
my_dataset_normal = dataset_path + "/NORMAL"

my_normal_test_dataset = dataset_path + "/NORMAL TEST"
my_covid_test_dataset = dataset_path + "/COVID TEST"

# %%
dirs = [dataset1_normal,dataset1_covid,dataset2_normal,dataset1_covid]

for dir in dirs:

  out_dir= my_dataset_covid
  file_tag="pos"

  if "normal" in dir.lower():
    out_dir = my_dataset_normal
    file_tag = "normal"
  
  count = len(os.listdir(out_dir))
  print("[INFO] "+dir+"/"+filename)
  for filename in os.listdir(dir):
    count +=1    
    ext = filename[ filename.rindex('.'): ]
    new_filename = out_dir + "/" + file_tag + str(count) + ext
    shutil.move(dir+"/"+filename,new_filename)

# %%
print(len(os.listdir(my_dataset_covid)))
print(len(os.listdir(my_dataset_normal)))
# Out:
# 600
# 1397

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Only selecting the image files that have label of Covid/SARS

# %%
file_data = pd.read_csv('/content/Chest_xray_Corona_Metadata.csv')
file_data.head()
# Out:
#    Unnamed: 0   X_ray_image_name  ... Label_2_Virus_category Label_1_Virus_category
# 0           0  IM-0128-0001.jpeg  ...                    NaN                    NaN
# 1           1  IM-0127-0001.jpeg  ...                    NaN                    NaN
# 2           2  IM-0125-0001.jpeg  ...                    NaN                    NaN
# 3           3  IM-0122-0001.jpeg  ...                    NaN                    NaN
# 4           4  IM-0119-0001.jpeg  ...                    NaN                    NaN
#
# [5 rows x 6 columns]

# %%
findings = file_data['Label_2_Virus_category']
images = file_data['X_ray_image_name']
images[5221]
# Out:
# 'kjr-21-e25-g001-l-a.jpg'

# %%
#covid_images = images[np.where(findings=='COVID-19')[0]]
covid_images = images[np.where(findings=='SARS')[0]]
len(covid_images)

# %%
dataset3_covid = collection_path + "/Covid19 Positive"
len(os.listdir(dataset3_covid))

# %%
count = len(os.listdir(my_covid_test_dataset))

# only run once
'''

for img in covid_images:
  count += 1

  print(dataset3_covid + "/" + img)
  ext = filename[ filename.rindex('.'): ]
  file_new = my_covid_test_dataset + "/testpos" + str(count) + ext
  print(file_new)

  shutil.copy(dataset3_covid + "/" + img,file_new)

'''

len(os.listdir(my_covid_test_dataset))

# %%
# only run once
'''
print(len(os.listdir(my_dataset_normal)))
for img in os.listdir(my_dataset_normal)[-147:]:
  print(img)
  src = my_dataset_normal + "/" + img
  dest = my_normal_test_dataset + "/" + img
  shutil.move(src,dest)
print(len(os.listdir(my_dataset_normal)))
'''

# %%
# Final Stats
train_covid_len = len(os.listdir(my_dataset_covid))
train_normal_len = len(os.listdir(my_dataset_normal))
test_covid_len = len(os.listdir(my_covid_test_dataset))
test_normal_len = len(os.listdir(my_normal_test_dataset))
total = train_covid_len + train_normal_len + test_covid_len + test_normal_len

print(f"No. of Training Covid Images: {train_covid_len}")
print(f"No. of Training Normal Images: {train_normal_len}")
print(f"No. of Testing Covid Images: {test_covid_len}")
print(f"No. of Testing Normal Images: {test_normal_len}")
print(f"Total count of images: {total}")
# Out:
# No. of Training Covid Images: 600
# No. of Training Normal Images: 1397
# No. of Testing Covid Images: 62
# No. of Testing Normal Images: 148
# Total count of images: 2207

# %%
# %%shell
# jupyter nbconvert --to html '/content/drive/MyDrive/ML Project/Data Collection.ipynb'
# Out:
# [NbConvertApp] Converting notebook /content/drive/MyDrive/ML Project/Data Collection.ipynb to html
# [NbConvertApp] Writing 295831 bytes to /content/drive/MyDrive/ML Project/Data Collection.html
